# %% [markdown]
# <h1>Filtering and Ordering</h1>

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 300)

# %%
df = pd.read_csv(r"C:\Users\dell\Downloads\vgsales.csv")
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df[df['Rank']<11]        #11 bcz starts from 0
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
specific_game = ['Devil May Cry','Tetris']
df[df['Name'].isin(specific_game)]
# Out:
#      Rank           Name Platform    Year   Genre Publisher  NA_Sales  \
# 5       6         Tetris       GB  1989.0  Puzzle  Nintendo     23.20
# 155   156         Tetris      NES  1988.0  Puzzle  Nintendo      2.97
# 475   476  Devil May Cry      PS2  2001.0  Action    Capcom      1.36
#
#      EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 5        2.26      4.22         0.58         30.26
# 155      0.69      1.81         0.11          5.58
# 475      0.86      0.64         0.13          2.99

# %%
df[df['Name'].isin(['Tetris'] )&(df['Year'] == 1989)]#can specify multiple values
# Out:
#    Rank    Name Platform    Year   Genre Publisher  NA_Sales  EU_Sales  \
# 5     6  Tetris       GB  1989.0  Puzzle  Nintendo      23.2      2.26
#
#    JP_Sales  Other_Sales  Global_Sales
# 5      4.22         0.58         30.26

# %%
#df[df['Name'].isin(['Devil May Cry'])]
df[df['Name'].isin(['Devil May Cry'])&(df['Year']>2000)]
# Out:
#      Rank           Name Platform    Year   Genre Publisher  NA_Sales  \
# 475   476  Devil May Cry      PS2  2001.0  Action    Capcom      1.36
#
#      EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 475      0.86      0.64         0.13          2.99

# %%
#df2 = df.set_index('Name')
#df2

# %%
df.iloc[550]
# Out:
# Rank                       551
# Name            Call of Duty 3
# Platform                  X360
# Year                    2006.0
# Genre                  Shooter
# Publisher           Activision
# NA_Sales                  1.49
# EU_Sales                  0.93
# JP_Sales                  0.02
# Other_Sales               0.27
# Global_Sales              2.71
# Name: 550, dtype: object

# %%
df2 = df.set_index('Name')
df2.loc['Call of Duty 3']
# Out:
#                 Rank Platform    Year    Genre   Publisher  NA_Sales  \
# Name
# Call of Duty 3   551     X360  2006.0  Shooter  Activision      1.49
# Call of Duty 3   713      Wii     NaN  Shooter  Activision      1.19
# Call of Duty 3  1240      PS3  2006.0  Shooter  Activision      0.60
# Call of Duty 3  1921      PS2  2006.0  Shooter  Activision      0.89
#
#                 EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Name
# Call of Duty 3      0.93      0.02         0.27          2.71
# Call of Duty 3      0.84      0.00         0.23          2.26
# Call of Duty 3      0.63      0.03         0.26          1.52
# Call of Duty 3      0.03      0.00         0.15          1.07

# %%
df[df['Rank']<11].sort_values(by=['Year','Global_Sales'],ascending=[True,False])#default is true,  First it sorts the year then global_sales
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 9     26.93      0.63      0.28         0.47         28.31
# ...
